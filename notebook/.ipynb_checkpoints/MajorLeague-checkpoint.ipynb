# %% [markdown]
# # Major League

# %% [markdown]
# Data from https://github.com/fivethirtyeight/data/tree/master/soccer-spi, using soccer dataset.

# %% [markdown]
# We are using regression models to determine the scores for each team using the other columns as features

# %%
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### Load data of matches

# %%
df = pd.read_csv("../data/spi_matches.csv")

# %%
df.shape
# Out:
# (20887, 22)

# %%
# Load ranking data
ranking = pd.read_csv("../data/spi_global_rankings.csv")

# %%
ranking = ranking.drop(columns=['prev_rank','league'])
ranking.head()
# Out:
#    rank             name   off   def    spi
# 0     1  Manchester City  2.92  0.20  93.78
# 1     2        Barcelona  3.12  0.38  92.41
# 2     3      Real Madrid  2.99  0.38  91.75
# 3     4    Bayern Munich  2.94  0.40  90.93
# 4     5         Juventus  2.66  0.29  90.72

# %% [markdown]
# ### Check the null data.

# %%
df.isnull().sum()
# Out:
# date               0
# league_id          0
# league             0
# team1              0
# team2              0
# spi1               0
# spi2               0
# prob1              0
# prob2              0
# probtie            0
# proj_score1        0
# proj_score2        0
# importance1    10327
# importance2    10327
# score1          6493
# score2          6493
# xg1            12200
# xg2            12200
# nsxg1          12200
# nsxg2          12200
# adj_score1     12200
# adj_score2     12200
# dtype: int64

# %% [markdown]
# ### Drop data.
# We dropped the columns that is provide no info, the columns missing too much data.

# %%
# The columns missing too much data
df = df.drop(columns=['league_id','importance1', 'importance2', 'xg1', 'xg2', 'nsxg1', 'nsxg2', 'adj_score1', 'adj_score2'])

# %% [markdown]
# Seasons are important to a team while the date is not so helpful.

# %%
df['Season'] = pd.to_datetime(df['date']).apply(lambda t: t.year)
df = df.drop(columns=['date'])

# %% [markdown]
# Drop the the rows missing score.

# %%
df = df.dropna(subset=["score1","score2"])
df.shape
# Out:
# (14394, 13)

# %%
df.head()
# Out:
#                     league          team1                team2   spi1   spi2  \
# 0           French Ligue 1         Bastia  Paris Saint-Germain  51.16  85.68
# 1           French Ligue 1      AS Monaco             Guingamp  68.85  56.48
# 2  Barclays Premier League      Hull City       Leicester City  53.57  66.81
# 3  Barclays Premier League        Burnley         Swansea City  58.98  59.74
# 4  Barclays Premier League  Middlesbrough           Stoke City  56.32  60.35
#
#     prob1   prob2  probtie  proj_score1  proj_score2  score1  score2  Season
# 0  0.0463  0.8380   0.1157         0.91         2.36     0.0     1.0    2016
# 1  0.5714  0.1669   0.2617         1.82         0.86     2.0     2.0    2016
# 2  0.3459  0.3621   0.2921         1.16         1.24     2.0     1.0    2016
# 3  0.4482  0.2663   0.2854         1.37         1.05     0.0     1.0    2016
# 4  0.4380  0.2692   0.2927         1.30         1.01     1.0     1.0    2016

# %% [markdown]
# ## Merge the match data with ranking data

# %% [markdown]
# Transfer teamname and league name into integer. Instead of encoding with random code, we use current ranking as code.Since the spi index is already existed in the matches data, we don't merge the spi from the ranking dataset.(def and off indexes are also changing each year)

# %%
ranking_new = ranking.drop(columns=['off','def','spi'])
ranking_new.rename(columns={ ranking.columns[0]: "rank1",ranking.columns[1]: "team1" }, inplace=True)
ranking_new.head(1)
# Out:
#    rank1            team1
# 0      1  Manchester City

# %%
df_new = pd.merge(df,ranking_new,on=["team1"])

# %%
ranking_new.rename(columns={ ranking_new.columns[0]: "rank2",ranking_new.columns[1]: "team2" }, inplace=True)
ranking_new.head(1)
# Out:
#    rank2            team2
# 0      1  Manchester City

# %%
df_new = pd.merge(df_new,ranking_new,on=["team2"])

# %%
df_new.head()
# Out:
#            league      team1     team2   spi1   spi2   prob1   prob2  probtie  \
# 0  French Ligue 1  AS Monaco  Guingamp  68.85  56.48  0.5714  0.1669   0.2617
# 1  French Ligue 1  AS Monaco  Guingamp  77.29  57.31  0.6807  0.1249   0.1944
# 2  French Ligue 1   Bordeaux  Guingamp  59.49  58.21  0.4603  0.2420   0.2977
# 3  French Ligue 1   Bordeaux  Guingamp  67.44  58.08  0.5544  0.1869   0.2587
# 4  French Ligue 1       Metz  Guingamp  46.98  61.14  0.3272  0.3764   0.2964
#
#    proj_score1  proj_score2  score1  score2  Season  rank1  rank2
# 0         1.82         0.86     2.0     2.0    2016     82    144
# 1         2.22         0.83     6.0     0.0    2017     82    144
# 2         1.48         1.02     3.0     0.0    2017    123    144
# 3         1.63         0.83     3.0     1.0    2017    123    144
# 4         1.25         1.49     2.0     2.0    2016    256    144

# %%
df_new.shape
# Out:
# (12587, 15)

# %% [markdown]
# Create mapping list

# %%
ranking_dict = ranking_new.set_index('team2').to_dict('dict')['rank2']

# %%
inv_ranking_dict = {v:k for k,v in ranking_dict.items()}

# %%
inv_ranking_dict
# Out:
# {1: 'Manchester City',
#  2: 'Barcelona',
#  3: 'Real Madrid',
#  4: 'Bayern Munich',
#  5: 'Juventus',
#  6: 'Paris Saint-Germain',
#  7: 'Liverpool',
#  8: 'Atletico Madrid',
#  9: 'Chelsea',
#  10: 'Tottenham Hotspur',
#  11: 'Napoli',
#  12: 'Ajax',
#  13: 'Arsenal',
#  14: 'Sevilla FC',
#  15: 'Valencia',
#  16: 'Internazionale',
#  17: 'Borussia Dortmund',
#  18: 'Manchester United',
#  19: 'PSV',
#  20: 'AS Roma',
#  21: 'FC Porto',
#  22: 'AC Milan',
#  23: 'FC Salzburg',
#  24: 'Real Betis',
#  25: 'Espanyol',
#  26: 'Getafe',
#  27: 'Real Sociedad',
#  28: 'Lazio',
#  29: 'RB Leipzig',
#  30: 'Young Boys',
#  31: 'Benfica',
#  32: 'PAOK Salonika',
#  33: 'Eibar',
#  34: 'Lyon',
#  35: 'Shakhtar Donetsk',
#  36: 'Villarreal',
#  37: 'Atalanta',
#  38: 'Dynamo Kiev',
#  39: 'Fiorentina',
#  40: 'Bayer Leverkusen',
#  41: 'Club Brugge',
#  42: 'CSKA Moscow',
#  43: 'Athletic Bilbao',
#  44: 'Leganes',
#  45: 'TSG Hoffenheim',
#  46: 'Celta Vigo',
#  47: 'Schalke 04',
#  48: 'FC Krasnodar',
#  49: 'Leicester City',
#  50: 'Alavés',
#  51: 'Marseille',
#  52: 'Zenit St Petersburg',
#  53: 'Galatasaray',
#  54: 'Girona FC',
#  55: 'Palmeiras',
#  56: 'Genk',
#  57: 'Borussia Monchengladbach',
#  58: 'AEK Athens',
#  59: 'Olympiacos',
#  60: 'Wolverhampton',
#  61: 'SD Huesca',
#  62: 'Real Valladolid',
#  63: 'Everton',
#  64: 'Eintracht Frankfurt',
#  65: 'Crystal Palace',
#  66: 'Guangzhou Evergrande',
#  67: 'Sporting CP',
#  68: 'AFC Bournemouth',
#  69: 'Torino',
#  70: 'Watford',
#  71: 'Levante',
#  72: 'Werder Bremen',
#  73: 'Besiktas',
#  74: 'Rayo Vallecano',
#  75: 'Istanbul Basaksehir',
#  76: 'Grêmio',
#  77: 'West Ham United',
#  78: 'Sampdoria',
#  79: 'FC Augsburg',
#  80: 'Ludogorets',
#  81: 'Newcastle',
#  82: 'AS Monaco',
#  83: 'Southampton',
#  84: 'Spartak Moscow',
#  85: 'Red Star Belgrade',
#  86: 'Stade Rennes',
#  87: 'Flamengo',
#  88: 'Sassuolo',
#  89: 'FC Midtjylland',
#  90: 'Standard Liege',
#  91: 'Montpellier',
#  92: 'Feyenoord',
#  93: 'Lille',
#  94: 'VfB Stuttgart',
#  95: 'Lokomotiv Moscow',
#  96: 'Hertha Berlin',
#  97: 'Internacional',
#  98: 'Braga',
#  99: 'Shanghai SIPG',
#  100: 'Mainz',
#  101: 'St Etienne',
#  102: 'Brighton and Hove Albion',
#  103: 'Boca Juniors',
#  104: 'River Plate',
#  105: 'VfL Wolfsburg',
#  106: 'FC Copenhagen',
#  107: 'Nice',
#  108: 'São Paulo',
#  109: 'Viktoria Plzen',
#  110: 'Trabzonspor',
#  111: 'Anderlecht',
#  112: 'Fulham',
#  113: 'West Bromwich Albion',
#  114: 'Angers',
#  115: 'Fenerbahce',
#  116: 'Basel',
#  117: 'Hannover 96',
#  118: 'Burnley',
#  119: 'Stoke City',
#  120: 'AIK',
#  121: 'Huddersfield Town',
#  122: 'Strasbourg',
#  123: 'Bordeaux',
#  124: 'Atlético Paranaense',
#  125: 'Genoa',
#  126: 'Nantes',
#  127: 'Cardiff City',
#  128: 'Club América',
#  129: 'SC Freiburg',
#  130: 'Celtic',
#  131: 'Atletico Mineiro',
#  132: 'Dinamo Zagreb',
#  133: 'Udinese',
#  134: 'AZ',
#  135: 'Toulouse',
#  136: 'Middlesbrough',
#  137: 'Tigres UANL',
#  138: 'Cagliari',
#  139: 'Brentford',
#  140: 'Dijon FCO',
#  141: 'Spal',
#  142: 'Racing Club',
#  143: 'Empoli',
#  144: 'Guingamp',
#  145: 'Kawasaki Frontale',
#  146: 'Santos',
#  147: 'BK Hacken',
#  148: 'Sheffield United',
#  149: '1. FC Nürnberg',
#  150: 'Malmo FF',
#  151: 'Leeds United',
#  152: 'FC Astana',
#  153: 'Rubin Kazan',
#  154: 'Bologna',
#  155: 'Fortuna Düsseldorf',
#  156: 'Cruzeiro',
#  157: 'Beijing Guoan',
#  158: 'Caen',
#  159: 'Reims',
#  160: 'Vitesse',
#  161: 'Rostov',
#  162: 'Nimes',
#  163: 'Monterrey',
#  164: 'Parma',
#  165: 'CA Independiente',
#  166: 'Atlanta United FC',
#  167: 'Atromitos',
#  168: 'Panathinaikos',
#  169: 'Bahía',
#  170: 'Jablonec',
#  171: 'Kasimpasa',
#  172: 'Amiens',
#  173: 'Swansea City',
#  174: 'Aston Villa',
#  175: 'Cruz Azul',
#  176: 'Chievo Verona',
#  177: 'Santos Laguna',
#  178: 'Urawa Red Diamonds',
#  179: 'Brondby',
#  180: 'LASK Linz',
#  181: 'KAA Gent',
#  182: 'Sporting Kansas City',
#  183: 'Fluminense',
#  184: 'Konyaspor',
#  185: 'Vasco da Gama',
#  186: 'Toluca',
#  187: 'Corinthians',
#  188: 'Kashima Antlers',
#  189: 'Rangers',
#  190: 'New York Red Bulls',
#  191: 'Birmingham',
#  192: 'Pachuca',
#  193: 'Rosenborg',
#  194: 'FC Cologne',
#  195: 'Rapid Vienna',
#  196: 'Derby County',
#  197: 'Bristol City',
#  198: 'Union Santa Fe',
#  199: 'Dinamo Moscow',
#  200: 'Norwich City',
#  201: 'Melbourne Victory',
#  202: 'Defensa y Justicia',
#  203: 'IFK Norrkoping',
#  204: 'Antwerp',
#  205: 'Botafogo',
#  206: 'FC Zurich',
#  207: 'Vorskla',
#  208: 'Guimaraes',
#  209: 'Frosinone',
#  210: 'Östersunds FK',
#  211: 'Sydney FC',
#  212: 'Gazovik Orenburg',
#  213: 'Molde',
#  214: 'Thun',
#  215: 'New York City FC',
#  216: 'Millwall',
#  217: 'BATE Borisov',
#  218: 'FC Luzern',
#  219: 'Preston North End',
#  220: 'SK Sturm Graz',
#  221: 'Ceará',
#  222: 'Velez Sarsfield',
#  223: 'Guadalajara',
#  224: 'Terek Grozny',
#  225: 'Yeni Malatyaspor',
#  226: 'Deportivo La Coruña',
#  227: 'Tijuana',
#  228: 'KV Kortrijk',
#  229: 'St. Truidense',
#  230: 'FC Arsenal Tula',
#  231: 'Pumas Unam',
#  232: 'Chapecoense AF',
#  233: 'Jiangsu Suning FC',
#  234: 'Málaga',
#  235: 'KV Oostende',
#  236: 'Rio Ave',
#  237: 'Shandong Luneng',
#  238: 'Asteras Tripolis',
#  239: 'Goztepe',
#  240: 'FC Sion',
#  241: 'Nottingham Forest',
#  242: 'Hibernian',
#  243: 'León',
#  244: 'FK Qarabag',
#  245: 'Necaxa',
#  246: 'FC Nordsjaelland',
#  247: 'Apollon Limassol',
#  248: 'Sheffield Wednesday',
#  249: 'Akhisar Belediye',
#  250: 'Talleres de Córdoba',
#  251: 'FC Ufa',
#  252: 'Vitoria Setubal',
#  253: 'Heerenveen',
#  254: 'San Lorenzo',
#  255: 'Changchun Yatai',
#  256: 'Metz',
#  257: 'Huracán',
#  258: 'FC Cincinnati',
#  259: 'Chaves',
#  260: 'Columbus Crew',
#  261: 'Godoy Cruz',
#  262: 'Portimonense',
#  263: 'Queens Park Rangers',
#  264: 'FC Xanthi',
#  265: 'Alanyaspor',
#  266: 'Seattle Sounders FC',
#  267: 'Mamelodi Sundowns',
#  268: 'Slavia Prague',
#  269: 'Argentinos Juniors',
#  270: 'Hull City',
#  271: 'Yokohama F. Marinos',
#  272: 'AEK Larnaca',
#  273: 'Toronto FC',
#  274: 'Ural Sverdlovsk Oblast',
#  275: 'St. Pölten',
#  276: 'Morelia',
#  277: 'Sivasspor',
#  278: 'Colon Santa Fe',
#  279: 'Sporting de Charleroi',
#  280: 'Brest',
#  281: 'Hebei China Fortune FC',
#  282: 'FK Austria Vienna',
#  283: 'Nagoya Grampus Eight',
#  284: 'Los Angeles FC',
#  285: 'Shanghai Greenland',
#  286: 'Hamburg SV',
#  287: 'Estudiantes',
#  288: 'Boavista',
#  289: 'Waasland-Beveren',
#  290: 'Santa Clara',
#  291: 'Belenenses',
#  292: 'Antalyaspor',
#  293: 'Querétaro',
#  294: 'Banfield',
#  295: 'Melbourne City',
#  296: 'FC Dallas',
#  297: 'América Mineiro',
#  298: 'Wigan',
#  299: 'FC Utrecht',
#  300: 'Cerezo Osaka',
#  301: 'Vítoria',
#  302: 'Blackburn',
#  303: 'Bursaspor',
#  304: 'Heracles',
#  305: 'Portland Timbers',
#  306: 'Louisville City FC',
#  307: 'Shimizu S-Pulse',
#  308: 'Tigre',
#  309: 'Atlético Tucumán',
#  310: 'Maritimo',
#  311: 'Feirense',
#  312: 'Willem II',
#  313: "Newell's Old Boys",
#  314: 'Sanfrecce Hiroshima',
#  315: 'Philadelphia Union',
#  316: 'Guizhou Renhe',
#  317: 'Caykur Rizespor',
#  318: 'Lanus',
#  319: 'Belgrano Cordoba',
#  320: 'Dalian Aerbin',
#  321: 'Aris Salonika',
#  322: 'C.D. Nacional',
#  323: 'GIF Sundsvall',
#  324: 'Puebla',
#  325: 'Reading',
#  326: 'AGF Aarhus',
#  327: 'Desportivo Aves',
#  328: 'Hammarby',
#  329: 'Atlas',
#  330: 'Eupen',
#  331: 'Aldosivi',
#  332: 'Videoton FC',
#  333: 'Grasshoppers Zürich',
#  334: 'Tondela',
#  335: 'Lobos de la BUAP',
#  336: '1. FC Union Berlin',
#  337: 'Guangzhou RF',
#  338: 'Las Palmas',
#  339: 'Los Angeles Galaxy',
#  340: 'Sport Recife',
#  341: 'FC Lugano',
#  342: 'Djurgardens IF',
#  343: 'Wolfsberger AC',
#  344: 'Gimnasia La Plata',
#  345: 'Anzhi Makhachkala',
#  346: 'Palermo',
#  347: 'Lorient',
#  348: 'Kayserispor',
#  349: 'Ipswich Town',
#  350: 'Sonderjyske',
#  351: 'SK Brann',
#  352: 'San Martin San Juan',
#  353: 'Real Salt Lake',
#  354: 'Panionios',
#  355: 'Montreal Impact',
#  356: 'Rosario Central',
#  357: 'St Gallen',
#  358: 'ADO Den Haag',
#  359: 'Moreirense',
#  360: 'Tianjin Quanujian',
#  361: 'Barnsley',
#  362: 'Odense BK',
#  363: 'Bolton',
#  364: 'Sunderland',
#  365: 'Giannina',
#  366: 'Tianjin Teda',
#  367: 'Granada',
#  368: 'AD Alcorcon',
#  369: 'Henan Jianye',
#  370: 'Rotherham United',
#  371: 'Cashpoint SC Rheindorf Altach',
#  372: 'F91 Dudelange',
#  373: 'San Martin de Tucuman',
#  374: 'DC United',
#  375: 'Lens',
#  376: 'AaB',
#  377: 'Troyes',
#  378: 'Kilmarnock',
#  379: 'New England Revolution',
#  380: 'Arminia Bielefeld',
#  381: 'Ankaragucu',
#  382: 'Chongqing Lifan',
#  383: 'PEC Zwolle',
#  384: 'Gamba Osaka',
#  385: 'Newcastle Jets',
#  386: 'Kashiwa Reysol',
#  387: 'Hearts',
#  388: 'FC Groningen',
#  389: 'FC Tokyo',
#  390: 'Holstein Kiel',
#  391: 'Metallurg Krasnoyarsk',
#  392: 'Odd BK',
#  393: 'Aberdeen',
#  394: 'Fortuna Sittard',
#  395: 'Houston Dynamo',
#  396: 'Cercle Brugge',
#  397: 'Paraná',
#  398: 'Krylia Sovetov',
#  399: 'Bidvest Wits',
#  400: 'FC Spartak Trnava',
#  401: 'VVV Venlo',
#  402: 'SV Zulte Waregem',
#  403: 'Haugesund',
#  404: 'Patronato',
#  405: 'Orange County SC',
#  406: 'Sarpsborg',
#  407: 'Stromsgodset',
#  408: 'Panetolikos',
#  409: 'Kaizer Chiefs',
#  410: 'Vegalta Sendai',
#  411: 'Kristiansund BK',
#  412: 'Jahn Regensburg',
#  413: 'SV Mattersburg',
#  414: 'Sporting Gijón',
#  415: 'Erzurumspor',
#  416: 'FC Trenkwalder Admira',
#  417: 'Dynamo Dresden',
#  418: 'Le Havre',
#  419: 'Crotone',
#  420: 'Orebro SK',
#  421: 'Excelsior',
#  422: 'Veracruz',
#  423: 'FC Ingolstadt 04',
#  424: 'Shonan Bellmare',
#  425: 'Guizhou Hengfeng Zhicheng',
#  426: 'Valerenga',
#  427: 'SC Paderborn',
#  428: 'Consadole Sapporo',
#  429: 'Reno 1868 FC',
#  430: 'Sagan Tosu',
#  431: 'Peterborough United',
#  432: 'Hartberg',
#  433: 'Real Zaragoza',
#  434: 'Emmen',
#  435: 'Orlando Pirates',
#  436: 'VfL Bochum',
#  437: 'KSC Lokeren',
#  438: 'Western Sydney FC',
#  439: 'Almeria',
#  440: 'Clermont Foot',
#  441: 'Albacete',
#  442: 'Osasuna',
#  443: '1. FC Heidenheim 1846',
#  444: 'Perth Glory',
#  445: 'Arizona United',
#  446: 'FC St. Pauli',
#  447: 'Benevento',
#  448: 'FC Wacker Innsbruck',
#  449: 'Chicago Fire',
#  450: 'Vancouver Whitecaps',
#  451: 'Brisbane Roar',
#  452: 'New York Red Bulls II',
#  453: 'Esbjerg',
#  454: 'Perugia',
#  455: 'Verona',
#  456: '1. FC Magdeburg',
#  457: 'SV Darmstadt 98',
#  458: 'Neuchatel Xamax',
#  459: 'Mallorca',
#  460: 'Minnesota United FC',
#  461: 'Fleetwood Town',
#  462: 'Foggia',
#  463: 'Vissel Kobe',
#  464: 'Adelaide United',
#  465: 'NAC',
#  466: 'Portsmouth',
#  467: 'Brescia',
#  468: 'Tromso',
#  469: 'MSV Duisburg',
#  470: 'Larissa',
#  471: 'Bethlehem Steel FC',
#  472: 'AC Horsens',
#  473: 'Cittadella',
#  474: 'Levadiakos',
#  475: 'Cadiz',
#  476: 'Randers FC',
#  477: 'San Jose Earthquakes',
#  478: 'Jubilo Iwata',
#  479: 'OFI Crete',
#  480: 'SpVgg Greuther Fürth',
#  481: 'Lamia',
#  482: 'SV Sandhausen',
#  483: 'Pittsburgh Riverhounds',
#  484: 'Numancia',
#  485: 'Mouscron-Peruwelz',
#  486: 'F.B.C Unione Venezia',
#  487: 'Paris FC',
#  488: 'Ranheim',
#  489: 'Apollon Smyrni',
#  490: 'Sacramento Republic FC',
#  491: 'Orléans',
#  492: 'Livingston',
#  493: 'Orlando City SC',
#  494: 'Real Oviedo',
#  495: 'Carolina Railhawks',
#  496: 'IF Elfsborg',
#  497: 'Lecce',
#  498: 'Tenerife',
#  499: 'SuperSport United',
#  500: 'Spezia',
#  501: 'Southend United',
#  502: 'Bodo/Glimt',
#  503: 'De Graafschap',
#  504: 'Erzgebirge Aue',
#  505: 'Charleston Battery',
#  506: 'Extremadura UD',
#  507: 'Salernitana',
#  508: 'Vendsyssel',
#  509: 'Cremonese',
#  510: 'Blackpool',
#  511: 'Luton Town',
#  512: 'Vejle',
#  513: 'Charlton Athletic',
#  514: 'V-Varen Nagasaki',
#  515: 'Niort',
#  516: 'Stabaek',
#  517: 'Hobro IK',
#  518: 'Portland Timbers 2',
#  519: 'Lillestrom',
#  520: 'Maritzburg Utd',
#  521: 'Polokwane City FC',
#  522: 'Scunthorpe',
#  523: 'Rayo Majadahonda',
#  524: 'Nashville SC',
#  525: 'Doncaster Rovers',
#  526: 'IFK Goteborg',
#  527: 'US Pescara',
#  528: 'Indy Eleven',
#  529: 'Lincoln City',
#  530: 'AC Ajaccio',
#  531: 'Lugo',
#  532: 'Grenoble',
#  533: 'Kalmar FF',
#  534: 'Colorado Rapids',
#  535: 'Swope Park Rangers',
#  536: 'Cordoba',
#  537: 'Reus Deportiu',
#  538: 'Accrington Stanley',
#  539: 'Real Monarchs SLC',
#  540: 'Milton Keynes Dons',
#  541: 'Wellington Phoenix',
#  542: 'Black Aces',
#  543: 'Saint Louis FC',
#  544: 'Elche',
#  545: 'Bloem Celtic',
#  546: 'Oklahoma City Energy FC',
#  547: 'Auxerre',
#  548: 'Sochaux',
#  549: 'Golden Arrows',
#  550: 'Shrewsbury Town',
#  551: 'IK Sirius',
#  552: 'LA Galaxy II',
#  553: 'Fresno FC',
#  554: 'Ascoli',
#  555: 'IK Start',
#  556: 'Gimnástic Tarragona',
#  557: 'Burton Albion',
#  558: 'Motherwell',
#  559: 'AmaZulu',
#  560: 'Beziers AS',
#  561: 'Exeter City',
#  562: 'Sandefjord',
#  563: 'Walsall',
#  564: 'Oldham Athletic',
#  565: 'Coventry City',
#  566: 'San Antonio FC',
#  567: 'Chateauroux',
#  568: 'Valenciennes',
#  569: 'Rochdale',
#  570: 'Wycombe Wanderers',
#  571: 'Chippa United',
#  572: 'St Johnstone',
#  573: 'Tampa Bay Rowdies',
#  574: 'Free State Stars',
#  575: 'Cosenza',
#  576: 'Carpi',
#  577: 'Central Coast Mariners',
#  578: 'Red Star FC 93',
#  579: 'Gillingham',
#  580: 'Mansfield Town',
#  581: 'Colchester United',
#  582: 'GFC Ajaccio',
#  583: 'Bury',
#  584: 'Oxford United',
#  585: 'Livorno',
#  586: 'Bristol Rovers',
#  587: 'Padova',
#  588: 'Dalkurd FF',
#  589: 'Charlotte Independence',
#  590: 'Highlands Park FC',
#  591: 'Las Vegas Lights FC',
#  592: 'Plymouth Argyle',
#  593: 'Rio Grande Valley FC Toros',
#  594: 'AS Nancy Lorraine',
#  595: 'St Mirren',
#  596: 'Bradford City',
#  597: 'Hamilton Academical',
#  598: 'Baroka FC',
#  599: 'Toronto FC II',
#  600: 'AFC Wimbledon',
#  601: 'Dundee',
#  602: 'Colorado Springs Switchbacks FC',
#  603: 'Penn FC',
#  604: 'Trelleborgs FF',
#  605: 'Yeovil Town',
#  606: 'Brommapojkarna',
#  607: 'Forest Green Rovers',
#  608: 'Tranmere Rovers',
#  609: 'Swindon Town',
#  610: 'Crawley Town',
#  611: 'Ottawa Fury FC',
#  612: 'Black Leopards',
#  613: 'Stevenage',
#  614: 'Northampton Town',
#  615: 'Newport County',
#  616: 'Seattle Sounders 2',
#  617: 'Notts County',
#  618: 'Carlisle United',
#  619: 'Atlanta United 2',
#  620: 'Crewe Alexandra',
#  621: 'Tulsa Roughnecks',
#  622: 'Morecambe',
#  623: 'Cheltenham Town',
#  624: 'Grimsby Town',
#  625: 'Port Vale',
#  626: 'Cambridge United',
#  627: 'Macclesfield',
#  628: 'Richmond Kickers'}

# %% [markdown]
# ### Encoding from string to number

# %%
from sklearn import preprocessing

le = preprocessing.LabelEncoder()
le = le.fit(df_new['league'])
df_new['league'] = le.transform(df_new['league'])

# %%
df_new = df_new.drop(columns=['team1','team2'])

# %%
df_new.head()
# Out:
#    league   spi1   spi2   prob1   prob2  probtie  proj_score1  proj_score2  \
# 0      11  68.85  56.48  0.5714  0.1669   0.2617         1.82         0.86
# 1      11  77.29  57.31  0.6807  0.1249   0.1944         2.22         0.83
# 2      11  59.49  58.21  0.4603  0.2420   0.2977         1.48         1.02
# 3      11  67.44  58.08  0.5544  0.1869   0.2587         1.63         0.83
# 4      11  46.98  61.14  0.3272  0.3764   0.2964         1.25         1.49
#
#    score1  score2  Season  rank1  rank2
# 0     2.0     2.0    2016     82    144
# 1     6.0     0.0    2017     82    144
# 2     3.0     0.0    2017    123    144
# 3     3.0     1.0    2017    123    144
# 4     2.0     2.0    2016    256    144

# %% [markdown]
# ### Correlation of dataset
# The following figure show the correlation of the features. The lighter the more related.

# %%
fig = plt.figure() 
ax=fig.add_subplot(figsize=(20,20))
ax=sns.heatmap(abs(df.corr()))
plt.show()

# %%
sns.pairplot(data=df_new[["spi1", "prob1", "probtie", "proj_score1","score1"]], hue='score1')
# Out:
# C:\Users\Christine\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\Christine\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\Christine\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# C:\Users\Christine\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)

# %% [markdown]
# ### Prediction with regression

# %% [markdown]
# We use score ratio as predict goal. The division can not be 0.

# %%
df_new['scoreratio'] = (df_new.score1+1)/(df_new.score2+1)

# %%
# df_new = df_new.drop(columns=['score1','score2'])

# %%
def ifwin(a, b):
    if a>b:
        return 1
    elif a==b:
        return 0
    else:
        return -1

# %%
df_new['win?'] = df_new.apply(lambda x: ifwin(x.score1,x.score2),axis=1)

# %%
df_new.head(10)
# Out:
#    league   spi1   spi2   prob1   prob2  probtie  proj_score1  proj_score2  \
# 0      11  68.85  56.48  0.5714  0.1669   0.2617         1.82         0.86
# 1      11  77.29  57.31  0.6807  0.1249   0.1944         2.22         0.83
# 2      11  59.49  58.21  0.4603  0.2420   0.2977         1.48         1.02
# 3      11  67.44  58.08  0.5544  0.1869   0.2587         1.63         0.83
# 4      11  46.98  61.14  0.3272  0.3764   0.2964         1.25         1.49
# 5      11  52.38  57.17  0.4107  0.3334   0.2559         1.52         1.34
# 6      11  52.23  58.83  0.3940  0.3051   0.3009         1.36         1.25
# 7      11  53.64  57.73  0.4047  0.2866   0.3087         1.18         0.94
# 8      11  62.31  55.93  0.5174  0.2128   0.2698         1.78         1.10
# 9      11  61.09  52.25  0.5314  0.1622   0.3064         1.29         0.57
#
#    score1  score2  Season  rank1  rank2  scoreratio  win?
# 0     2.0     2.0    2016     82    144         1.0     0
# 1     6.0     0.0    2017     82    144         7.0     1
# 2     3.0     0.0    2017    123    144         4.0     1
# 3     3.0     1.0    2017    123    144         2.0     1
# 4     2.0     2.0    2016    256    144         1.0     0
# 5     1.0     3.0    2017    256    144         0.5    -1
# 6     1.0     1.0    2016    158    144         1.0     0
# 7     0.0     0.0    2017    158    144         1.0     0
# 8     1.0     1.0    2017     91    144         1.0     0
# 9     1.0     1.0    2018     91    144         1.0     0

# %%
fig = plt.figure() 
ax=fig.add_subplot(figsize=(20,20))
ax=sns.heatmap(abs(df_new.corr()))
plt.show()

# %% [markdown]
# ### Split the data set

# %% [markdown]
# First, we try make score ratio as goal. We train on 80% of the data,and using the rest 20% as testing.

# %%
data_x = df_new.drop(columns=['scoreratio','win?','score1','score2'])
data_y = df_new[['win?']]

perc_test = 0.20
X_train, X_test, y_train, y_test = train_test_split(data_x, data_y, test_size=perc_test)

# %% [markdown]
# ### Try ifwin

# %%
regression_model1 = LinearRegression()
regression_model1.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
for idx, col_name in enumerate(X_train.columns):
    print("The coefficient for {} is {}".format(col_name, regression_model.coef_[0][idx]))
# Out:
# The coefficient for league is -0.0005015442882424954
# The coefficient for spi1 is -0.01713393584640503
# The coefficient for spi2 is 0.019445949314997282
# The coefficient for prob1 is 85.51634994038078
# The coefficient for prob2 is 84.97985660699825
# The coefficient for probtie is 82.92606722922363
# The coefficient for proj_score1 is 0.4271444863861854
# The coefficient for proj_score2 is -0.648105790664767
# The coefficient for Season is -0.005101727606422361
# The coefficient for rank1 is -0.0013504953473963885
# The coefficient for rank2 is 0.001656293021630251

# %%
regression_model.score(X_test, y_test)
# Out:
# -2.3775097105751772

# %%
predictions = regression_model.predict(X_test)

# %%
plt.scatter( y_test,predictions)

# %% [markdown]
# The X-axis is ifwin index. We can see that on average, the win cases showing a trend of higher score. But the method can't distinguish win from lose for most cases (overlaped a lot).

# %% [markdown]
# ### Try score ratio

# %%
data_x = df_new.drop(columns=['scoreratio','win?','score1','score2'])
data_y = df_new[['scoreratio']]

perc_test = 0.20
X_train, X_test, y_train, y_test = train_test_split(data_x, data_y, test_size=perc_test)

# %%
#Train the model
regression_model = LinearRegression()
regression_model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
for idx, col_name in enumerate(X_train.columns):
    print("The coefficient for {} is {}".format(col_name, regression_model.coef_[0][idx]))
# Out:
# The coefficient for league is -0.0006832758193696363
# The coefficient for spi1 is -0.019782173262263118
# The coefficient for spi2 is 0.021310057496545836
# The coefficient for prob1 is 26.257283827362365
# The coefficient for prob2 is 25.729781137594507
# The coefficient for probtie is 24.046950205558694
# The coefficient for proj_score1 is 0.4717284164331229
# The coefficient for proj_score2 is -0.646277150812043
# The coefficient for Season is -0.010659920505835762
# The coefficient for rank1 is -0.0014287243258051337
# The coefficient for rank2 is 0.0016657834390683686

# %% [markdown]
# Scoring model

# %%
regression_model.score(X_test, y_test)
# Out:
# 0.1813333594928169

# %%
predictions = regression_model.predict(X_test)

# %%
plt.scatter( y_test,predictions)
